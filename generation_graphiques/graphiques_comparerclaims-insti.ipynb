# %%
import json
def ouvrir_json(chemin):
  f = open(chemin, encoding="utf-8")
  toto = json.load(f)
  f.close()
  return toto

dico_compte_partiemaj = ouvrir_json("dico_compte_partiemaj_insti_sw_corr.json") #seulement sur articles avec claims de force diff

dico_compteur = ouvrir_json("dico_compteur_insti_sw_corr.json") #sur tous

dico_total_partie = ouvrir_json("dico_total_partie_insti_sw_corr.json") #sur tous

dico_nb_strength = ouvrir_json("stopwords/dico_nb_strength_sw_corr.json")
dico_nb_strength_insti = ouvrir_json("dico_nb_strength_insti_sw_corr.json")

# %%
import numpy as np
import matplotlib.pyplot as plt
  
N = 3
ind = np.arange(N) 
width = 0.2
  
xlabels = []
xvals = []

for x, y in dico_compteur["abstract"].items():
    xlabels.append(x)
    xvals.append(y)
bar1 = plt.bar(ind, xvals, width, color = 'r')
  
ylabels = []
yvals = []

for x, y in dico_compteur["intro"].items():
    ylabels.append(x)
    yvals.append(y)
bar2 = plt.bar(ind+width, yvals, width, color='g')

zzlabels = []
zzvals = []

for x, y in dico_compteur["corps"].items():
    zzlabels.append(x)
    zzvals.append(y)
bar4 = plt.bar(ind+width*2, zzvals, width, color = 'grey')
  
zlabels = []
zvals = []

for x, y in dico_compteur["ccl"].items():
    zlabels.append(x)
    zvals.append(y)
bar3 = plt.bar(ind+width*3, zvals, width, color = 'b')

  
plt.xlabel("Claim strength")
plt.ylabel('Nombre de claims')
plt.title("Nombre de claims par catégorie selon la partie (tout)")
  
plt.xticks(ind+width,['0', '1', '2'])
plt.legend( (bar1, bar2, bar4,bar3), ('Abstract', 'Intro', 'Corps', 'Conclusion') )
plt.savefig("stopwords/corr/proportion_claims_3bars_tt_insti_sw.png",bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

dico_compteur = ouvrir_json("partie_force_insti_corr.json")
  
N = 3
ind = np.arange(N) 
width = 0.2
  
xlabels = []
xvals = []

for x, y in dico_compteur["abstract"].items():
    xlabels.append(x)
    xvals.append(y)
bar1 = plt.bar(ind, xvals, width, color = 'r')
  
ylabels = []
yvals = []

for x, y in dico_compteur["intro"].items():
    ylabels.append(x)
    yvals.append(y)
bar2 = plt.bar(ind+width, yvals, width, color='g')

zzlabels = []
zzvals = []

for x, y in dico_compteur["corps"].items():
    zzlabels.append(x)
    zzvals.append(y)
bar4 = plt.bar(ind+width*2, zzvals, width, color = 'b')
  
zlabels = []
zvals = []

for x, y in dico_compteur["ccl"].items():
    zlabels.append(x)
    zvals.append(y)
bar3 = plt.bar(ind+width*3, zvals, width, color = 'grey')

  
plt.xlabel("Claim strength")
plt.ylabel('Nombre de claims')
plt.title("Nombre de claims par catégorie selon la partie (tout)")
  
plt.xticks(ind+width,['0', '1', '2'])
plt.legend( (bar1, bar2, bar4,bar3), ('Abstract', 'Intro', 'Corps', 'Conclusion') )
plt.savefig("stopwords/corr/proportion_claims_3bars_tt_insti_sw_tt.png")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

dico_compteur_i = ouvrir_json("force_insti_sw_corr.json")
dico_compteur_noi = ouvrir_json("force_noinsti_sw_corr.json")
  
    
N = 2
ind = np.arange(N) 
width = 0.25

n='0'
xvals = [dico_compteur_i[n],dico_compteur_noi[n]] #toutes les valeurs de 0
bar1 = plt.bar(ind, xvals, width, color = 'r')
 
n = '1'
yvals = [dico_compteur_i[n],dico_compteur_noi[n]] #toutes les valeurs de 1
bar2 = plt.bar(ind+width, yvals, width, color='g')
 
n='2'
zvals = [dico_compteur_i[n],dico_compteur_noi[n]] #toutes les valeurs de 0 #toutes les valeurs de 2
bar3 = plt.bar(ind+width*2, zvals, width, color = 'b')
  
#plt.xlabel("Genre")
plt.ylabel('Nombre de claims')
#plt.title("Nombre de claims par continent des auteurs selon la force")
  
plt.xticks(ind+width,['Avec institutions','Sans institution'])
plt.legend( (bar1, bar2, bar3), ('0', '1', '2') )
plt.savefig("stopwords/corr/proportion_claims_3bars_strength_insti-no_sw.png",bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

dico_compteur_i = ouvrir_json("force_insti_sw_corr.json")
dico_compteur_noi = ouvrir_json("force_noinsti_sw_corr.json")
  
    
N = 2
ind = np.arange(N) 
width = 0.25

n='0'
xvals = [dico_compteur_i[n]/sum(dico_compteur_i.values()),dico_compteur_noi[n]/sum(dico_compteur_noi.values())] #toutes les valeurs de 0
bar1 = plt.bar(ind, xvals, width, color = 'r')
 
n = '1'
yvals = [dico_compteur_i[n]/sum(dico_compteur_i.values()),dico_compteur_noi[n]/sum(dico_compteur_noi.values())] #toutes les valeurs de 1
bar2 = plt.bar(ind+width, yvals, width, color='g')
 
n='2'
zvals = [dico_compteur_i[n]/sum(dico_compteur_i.values()),dico_compteur_noi[n]/sum(dico_compteur_noi.values())] #toutes les valeurs de 0 #toutes les valeurs de 2
bar3 = plt.bar(ind+width*2, zvals, width, color = 'b')
  
#plt.xlabel("Genre")
plt.ylabel('Nombre de claims')
#plt.title("Nombre de claims par continent des auteurs selon la force")
  
plt.xticks(ind+width,['Avec institutions','Sans institution'])
plt.legend( (bar1, bar2, bar3), ('0', '1', '2') )
plt.ylim(0,1)
plt.savefig("stopwords/corr/proportion_claims_3bars_strength_insti-no_sw_pct.png",bbox_inches='tight')
plt.show()

# %%
#valeurs semblent identiques mais en fait non, donc pas un bug de graphique
print(xvals,yvals,zvals)
# Out:
# [0.14299547910590582, 0.12040122801258905] [0.7012514109888095, 0.7279450097507288] [0.15575310990528468, 0.15165376223668206]

# %%
import numpy as np
import matplotlib.pyplot as plt

dico_compteur_i = ouvrir_json("partie_insti_sw_corr.json")
dico_compteur_noi = ouvrir_json("partie_noinsti_sw_corr.json")
  
    
N = 2
ind = np.arange(N) 
width = 0.2

n='abstract'
xvals = [dico_compteur_i[n]/sum(dico_compteur_i.values()),dico_compteur_noi[n]/sum(dico_compteur_noi.values())] #toutes les valeurs de 0
bar1 = plt.bar(ind, xvals, width, color = 'r')
 
n = 'intro'
yvals = [dico_compteur_i[n]/sum(dico_compteur_i.values()),dico_compteur_noi[n]/sum(dico_compteur_noi.values())] #toutes les valeurs de 1
bar2 = plt.bar(ind+width, yvals, width, color='g')
 
n='corps'
zvals = [dico_compteur_i[n]/sum(dico_compteur_i.values()),dico_compteur_noi[n]/sum(dico_compteur_noi.values())] #toutes les valeurs de 0 #toutes les valeurs de 2
bar3 = plt.bar(ind+width*2, zvals, width, color = 'b')

n='ccl'
zzvals = [dico_compteur_i[n]/sum(dico_compteur_i.values()),dico_compteur_noi[n]/sum(dico_compteur_noi.values())] #toutes les valeurs de 0 #toutes les valeurs de 2
bar4 = plt.bar(ind+width*3, zzvals, width, color = 'grey')
  
#plt.xlabel("Genre")
plt.ylabel('Nombre de claims')
#plt.title("Nombre de claims par continent des auteurs selon la force")
  
plt.xticks(ind+width,['Avec institutions','Sans institution'])
plt.legend( (bar1, bar2, bar3,bar4), ('Abstract', 'Introduction', 'Corps','Conclusion') )
plt.ylim(0,1)
plt.savefig("stopwords/corr/proportion_claims_3bars_partie_insti-no_sw_pct.png",bbox_inches='tight')
plt.show()

# %%
print(xvals, yvals, zvals, zzvals)
# Out:
# [0.059444886920348605, 0.06235446313065977] [0.07205640517295715, 0.08637408043868626] [0.7686092950499361, 0.7223127570427295] [0.09988941285675813, 0.12895869938792454]

# %%
import numpy as np
import matplotlib.pyplot as plt

dico_compteur_i = ouvrir_json("partie_insti_sw_corr.json")
dico_compteur_noi = ouvrir_json("partie_noinsti_sw_corr.json")
  
    
N = 2
ind = np.arange(N) 
width = 0.2

n='abstract'
xvals = [dico_compteur_i[n],dico_compteur_noi[n]] #toutes les valeurs de 0
bar1 = plt.bar(ind, xvals, width, color = 'r')
 
n = 'intro'
yvals = [dico_compteur_i[n],dico_compteur_noi[n]] #toutes les valeurs de 1
bar2 = plt.bar(ind+width, yvals, width, color='g')
 
n='corps'
zvals = [dico_compteur_i[n],dico_compteur_noi[n]] #toutes les valeurs de 0 #toutes les valeurs de 2
bar3 = plt.bar(ind+width*2, zvals, width, color = 'b')

n='ccl'
zzvals = [dico_compteur_i[n],dico_compteur_noi[n]] #toutes les valeurs de 0 #toutes les valeurs de 2
bar4 = plt.bar(ind+width*3, zzvals, width, color = 'grey')
  
#plt.xlabel("Genre")
plt.ylabel('Nombre de claims')
#plt.title("Nombre de claims par continent des auteurs selon la force")
  
plt.xticks(ind+width,['Avec institutions','Sans institution'])
plt.legend( (bar1, bar2, bar3,bar4), ('Abstract', 'Introduction', 'Corps','Conclusion') )
plt.savefig("proportion_claims_3bars_partie_insti-no_sw_corr.png",bbox_inches='tight')
plt.show()

# %%
#comparer proportions claims dans insti vs total (overlapping)
total = [{'total_articles': 7197}, {'articles_contenant_claims': 7126}, {'articles_contenant_insti': 2603}, {'total_claims' : 15567}]
insti = [{'articles_contenant_institution': 2603}, {'articles_contenants_claims+insti': 2592}, {'articles_contenant_claims+insti': 2592}, {'claims_dans_articles_insti' : 9736}]

for i in range(len(total)):
    names_t = list(total[i].keys())
    values_t = list(total[i].values())

    names_i = list(insti[i].keys())
    values_i = list(insti[i].values())

    plt.bar(range(len(total[i])), values_t, tick_label=names_t,alpha=0.5)
    plt.bar(range(len(total[i])), values_i,alpha=0.5)
    plt.title(f'Proportion des {names_i} parmi {names_t}')
    plt.savefig("proportions_totalvsinsti_%i_corr.png"%i,bbox_inches='tight')
    plt.show()

# %%
#### VERIFIER D'OU VIENT LE 349046
#comparer proportions claims dans insti vs total (overlapping)
total = [{"Total d'articles": 7197}, {'Articles contenant des claims': 7126}, {'Articles contenant des institutions': 2603}, {'Total de claims' : 513915}]
insti = [{'Articles contenant des institutions':2603}, {'Articles contenant des claims et des institutions': 2592}, {'Articles contenant des claims et des institutions': 2592}, {'Claims dans articles avec institutions' : 349046}]

for i in range(len(total)):
    names_t = list(total[i].keys())
    values_t = list(total[i].values())

    names_i = list(insti[i].keys())
    values_i = list(insti[i].values())
    print(values_t,values_i)

    plt.bar(range(len(total[i])), values_t, tick_label=names_t,alpha=0.5)
    plt.bar(range(len(total[i])), values_i,alpha=0.5)
    #plt.title(f'Proportion des {names_i} parmi {names_t}')
    plt.savefig("stopwords/corr/proportions_totalvsinsti_%i.png"%i,bbox_inches='tight')
    plt.show()
# Out:
# [7197] [2603]
# [7126] [2592]
# [2603] [2592]
# [513915] [349046]
